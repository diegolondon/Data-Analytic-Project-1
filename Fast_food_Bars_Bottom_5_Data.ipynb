# %% [markdown]
#   ANALYSIS OF DATA FOR BOTTOM 5 AVERAGE HOUSE PRICES IN LONDON BOROUGHS
#
# - With the use of Places API Playground we looked locating the number of fast food places and bars
# - Focus was given to the bottom 5 boroughs by average house prices:
#     (i) Barking & Dagenham (ii) Bexley (iii) Newham (iv) Havering (v) Croydon
# - On analysis of the data it can be seen that Westminster is an outlier and skewing the data for both number of fast food placed  and number of bars.
# - Barking and Havering have the lowest figures for fast food places.
# - Barking and Havering also show the lowest figures for fast food places.

# %% [markdown]
# ![Picture2_API_Bark.png](attachment:Picture2_API_Bark.png)

# %%
# Dependencies
import requests
import json

# Import the API key
from config import geoapify_key

# could not import from config as showing import error message

# %%
# From playground APIs - Royal Borough of Barking & Dagenham - categories = catering.fast_food

url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:5180699a07610bc13f59512d0b4fa0c54940f00101f9018bd4020000000000c002069203264c6f6e646f6e20426f726f756768206f66204261726b696e6720616e6420446167656e68616d&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': "McDonald's",
#     'country': 'United Kingdom',
#     'country_code': 'gb',
#     'state': 'England',
#     'county': 'Greater London',
#     'city': 'London',
#     'postcode': 'RM10 9LU',
#     'district': 'London Borough of Barking and Dagenham',
#     'suburb': 'Dagenham',
#     'street': 'Ballards Road',
#     'lon': 0.15521245275090506,
#     'lat': 51.5292459,
#     'state_code': 'ENG',
#     'formatted': "McDonald's, Ballards Road, London RM10 9LU, United Kingdom",
#     'address_line1': "McDonald's",
#     'address_line2': 'Ballards Road, London RM10 9LU, United Kingdom',
#     'categories': ['building',
#      'building.catering',
#      'catering',
#      'catering.fast_food',
#      'catering.fast_food.burger',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.catering', 'details.facilities'],
# ...

# %%
# To make data subscriptable
borough_data = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_Bark = len(borough_data["features"])
print(f"There are {number_fast_food_Bark} fast food places in Barking & Dagenham")
# Out:
# There are 76 fast food places in Barking & Dagenham

# %%
# From Playground APIs Borough of Bexley
url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:51e2afc91af510c13f59b79c4b7155b54940c00208e2031967656f6e616d65733a6c6f63616c6974793a33333333313234&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())

# To make data subscriptable
borough_data_2 = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_Bex = len(borough_data_2["features"])
print(f"There are {number_fast_food_Bex} fast food places in Bexley")
# Out:
# There are 105 fast food places in Bexley

# %%
# From Playground APIs Borough of Newham
url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:51761ee368d238a33f5921c37b7971c34940f00101f901a1d4020000000000c002069203184c6f6e646f6e20426f726f756768206f66204e657768616d&limit=250&apiKey=geoapify_key"
response = requests.get(url)
(response.json())

# To make data subscriptable
borough_data_3 = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_New = len(borough_data_3["features"])
print(f"There are {number_fast_food_New} fast food places in Newham")
# Out:
# There are 206 fast food places in Newham

# %%
# From Playground APIs Borough of Havering
url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:51fbc906389736cc3f59fc14ad5614c84940f00101f90186d4020000000000c0020692031a4c6f6e646f6e20426f726f756768206f66204861766572696e67&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())

# To make data subscriptable
borough_data_4 = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_Hav = len(borough_data_4["features"])
print(f"There are {number_fast_food_Hav} fast food places in Havering")
# Out:
# There are 79 fast food places in Havering

# %%
# From Playground APIs Borough of Croydon
url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:516f8bd8f22150b6bf593b4657c67bad4940f00101f901c3ca000000000000c002069203194c6f6e646f6e20426f726f756768206f662043726f79646f6e&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())

# To make data subscriptable
borough_data_5 = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_Croy = len(borough_data_5["features"])
print(f"There are {number_fast_food_Croy} fast food places in Croydon")
# Out:
# There are 250 fast food places in Croydon

# %%
# From playground APIs - Royal Borough of Barking & Dagenham - categories = catering.bar

url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:5180699a07610bc13f59512d0b4fa0c54940f00101f9018bd4020000000000c002069203264c6f6e646f6e20426f726f756768206f66204261726b696e6720616e6420446167656e68616d&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Kings Lounge',
#     'country': 'United Kingdom',
#     'country_code': 'gb',
#     'state': 'England',
#     'county': 'Greater London',
#     'city': 'London',
#     'town': 'Barking',
#     'postcode': 'IG11 8HG',
#     'district': 'Roding Riverside',
#     'street': 'Linton Road',
#     'housenumber': '2',
#     'lon': 0.07939270363756744,
#     'lat': 51.53848395,
#     'state_code': 'ENG',
#     'formatted': 'Kings Lounge, 2 Linton Road, London IG11 8HG, United Kingdom',
#     'address_line1': 'Kings Lounge',
#     'address_line2': '2 Linton Road, London IG11 8HG, United Kingdom',
#     'categories': ['building',
#      'building.catering',
#      'catering',
#      'catering.bar'],
#     'details': ['details', 'details.building'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
# ...

# %%
# To make data subscriptable
borough_data = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Bark = len(borough_data["features"])
print(f"There are {number_of_bars_Bark} bars in Barking & Dagenham")
# Out:
# There are 4 bars in Barking & Dagenham

# %%
# From Playground APIs Borough of Bexley - Catering.bar
url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:51e2afc91af510c13f59b79c4b7155b54940c00208e2031967656f6e616d65733a6c6f63616c6974793a33333333313234&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())

# To make data subscriptable
borough_data_2 = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Bex = len(borough_data_2["features"])
print(f"There are {number_of_bars_Bex} bars in Bexley")
# Out:
# There are 105 bars in Bexley

# %%
# From Playground APIs Borough of Newham - Catering.bar
url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:51761ee368d238a33f5921c37b7971c34940f00101f901a1d4020000000000c002069203184c6f6e646f6e20426f726f756768206f66204e657768616d&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())

# To make data subscriptable
borough_data_3 = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Newh = len(borough_data_3["features"])
print(f"There are {number_of_bars_Newh} bars in Newham")
# Out:
# There are 25 bars in Newham

# %%
# From Playground APIs Borough of Havering - Catering.bar
url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:51eb1c03b2d7bbcb3f596666666666c64940c00208e2031967656f6e616d65733a6c6f63616c6974793a33333333313533&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())

# To make data subscriptable
borough_data_4 = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Hav = len(borough_data_4["features"])
print(f"There are {number_of_bars_Hav} bars in Havering")
# Out:
# There are 3 bars in Havering

# %%
# From Playground API's Borough of Croydon - Catering.bar
url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:516f8bd8f22150b6bf593b4657c67bad4940f00101f901c3ca000000000000c002069203194c6f6e646f6e20426f726f756768206f662043726f79646f6e&limit=250&apiKey=geoapify_key"

response = requests.get(url)
(response.json())

# To make data subscriptable
borough_data_5 = requests.get(url).json()

# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Croy = len(borough_data_5["features"])
print(f"There are {number_of_bars_Hav} bars in Croydon")
# Out:
# There are 3 bars in Croydon

# %%
import pandas as pd
Boroughs_df = pd.DataFrame({"Borough":["Barking & Dagenham", "Bexley", "Newham", "Havering", "Croydon"],
                              "Number of Bars": [number_of_bars_Bark,number_of_bars_Bex,number_of_bars_Newh,number_of_bars_Hav,number_of_bars_Croy]
                                        
    
    
})
Boroughs_df.head()
# Out:
#               Borough  Number of Bars
# 0  Barking & Dagenham               4
# 1              Bexley             105
# 2              Newham              25
# 3            Havering               3
# 4             Croydon              25

# %%
Boroughs_df["Number of Fast Food Places"]= [number_fast_food_Bark,number_fast_food_Bex,number_fast_food_New, number_fast_food_Hav,number_fast_food_Croy]
Boroughs_df
# Out:
#               Borough  Number of Bars  Number of Fast Food Places
# 0  Barking & Dagenham               4                          76
# 1              Bexley             105                         105
# 2              Newham              25                         206
# 3            Havering               3                          79
# 4             Croydon              25                         250

# %%
import matplotlib.pyplot as plt

plt.bar(x= Boroughs_df['Borough'], height =Boroughs_df['Number of Fast Food Places'])
plt.xticks(rotation=45)
plt.xlabel("Boroughs")
plt.ylabel("Number of Fast Food Places")
plt.show()

# %%
plt.bar(x= Boroughs_df['Borough'], height =Boroughs_df['Number of Bars'])
plt.xticks(rotation=45)
plt.xlabel("Boroughs")
plt.ylabel("Number of Bars")
plt.show()

# %% [markdown]
#    ANALYSIS OF DATA FOR TOP 5 AVERAGE HOUSE PRICES IN LONDON BOROUGHS
#
# - With the use of Places API Playground we looked locating the number of fast food places and bars
# - Focus was given to the top 5 boroughs by average house prices:
#     (i) Kensington & Chelsea (ii) Westminster (iii) Camden (iv) Hammersmith & Fulham (v) Richmond upon Thames
# - On analysis of the data it can be seen that Westminster is an outlier and skewing the data for both number of fast food placed  and number of bars.
# - Hammesmith and Richmond show the lowest figures for bars.
# - Kensington and Richmond show the lowest figures for fast food places

# %% [markdown]
# ![Picture1_API_Ken.png](attachment:Picture1_API_Ken.png)

# %%
# Dependencies
import requests
import json

# Import the API key
from config import geoapify_key

# %%
import requests

# From playground APIs - Royal Borough of Kensington and London - categories = catering.bar

url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:51d6acea30389ac8bf59b8d8034327c04940f00101f90151ca000000000000c00206920327526f79616c20426f726f756768206f66204b656e73696e67746f6e20616e64204368656c736561&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Olives Bar', 'country': 'United Kingdom', 'country_code': 'gb', 'state': 'England', 'county': 'Greater London', 'city': 'London', 'postcode': 'SW7 4SS', 'district': 'Royal Borough of Kensington and Chelsea', 'neighbourhood': 'The Boltons', 'suburb': 'South Kensington', 'street': 'Gloucester Road', 'housenumber': '140', 'lon': -0.1823815, 'lat': 51.4938009, 'state_code': 'ENG', 'formatted': 'Olives Bar, 140 Gloucester Road, London SW7 4SS, United Kingdom', 'address_line1': 'Olives Bar', 'address_line2': '140 Gloucester Road, London SW7 4SS, United Kingdom', 'categories': ['catering', 'catering.bar'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Olives Bar', 'phone': '+44 20 7331 6308', 'osm_id': 1360505700, '
# ...

# %%
# To make data subscriptable
borough_data = requests.get(url).json()

# %%
# Print the json (pretty printed)
print(json.dumps(borough_data, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -0.1823815,
#                     51.49380089917333
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Olives Bar",
#                 "address_line2": "140 Gloucester Road, London SW7 4SS, United Kingdom",
#                 "categories": [
#                     "catering",
#                     "catering.bar"
#                 ],
#                 "city": "London",
#                 "country": "United Kingdom",
#                 "country_code": "gb",
#                 "county": "Greater London",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 140,
# ...

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Ken = len(borough_data["features"])
print(f"There are {number_of_bars_Ken} bars in Kensington and London")
# Out:
# There are 34 bars in Kensington and London

# %%
for b in range(number_of_bars): 
    print (borough_data["features"][b]["properties"]["name"])
# Out:
# Olives Bar
# JuJu
# The Enterprise
# Cave of Lanka
# Zefi Bar
# Evans & Peel Detective Agency
# Juicebaby
# The Stables Bar
# Trailer Happiness
# The Little Yellow Door
# Ariadne's Nectar Bar
# Jak's Bars
# Bottles Chelsea
# Kosmopol
# Wine Not?
# Azteca
# The Portobello Star
# The Distillery
# 140 Portobello
# Mau Mau Bar
# The Chilled Eskimo
# Piano
# Kens Bar & Garden
# Eclipse
# Janet’s Bar
# Eclipse
# Tequila Tex-Mex
# Polo Bar
# Jak’s
# Barts
# Elgin
# Negozio Classica
# Barts
# amaro

# %%
import requests

# From playground APIs - Borough of Westminster - categories = catering.bar

url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:519b3228a20f8ac4bf593c055885b8c14940f00101f90145ca000000000000c0020692031343697479206f6620576573746d696e73746572&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Village', 'country': 'United Kingdom', 'country_code': 'gb', 'state': 'England', 'county': 'Greater London', 'city': 'London', 'postcode': 'W1D 6QD', 'suburb': 'Soho', 'street': 'Wardour Street', 'housenumber': '81', 'lon': -0.13338116822608898, 'lat': 51.5124198, 'state_code': 'ENG', 'formatted': 'Village, 81 Wardour Street, London W1D 6QD, United Kingdom', 'address_line1': 'Village', 'address_line2': '81 Wardour Street, London W1D 6QD, United Kingdom', 'categories': ['building', 'building.catering', 'catering', 'catering.bar'], 'details': ['details', 'details.building', 'details.catering', 'details.contact', 'details.facilities', 'details.payment', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'food': 'no', 'name': 'Village', 'lgbt
# ...

# %%
# To make data subscriptable
borough_data_2 = requests.get(url).json()

# %%
# Print the json (pretty printed)
print(json.dumps(borough_data_2, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -0.13338082474369012,
#                     51.51244134713981
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Village",
#                 "address_line2": "81 Wardour Street, London W1D 6QD, United Kingdom",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.bar"
#                 ],
#                 "city": "London",
#                 "country": "United Kingdom",
#                 "country_code": "gb",
#                 "county": "Greater London",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
# ...

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_West = len(borough_data_2["features"])
print(f"There are {number_of_bars_West} bars in Westminster")
# Out:
# There are 181 bars in Westminster

# %%
import requests

# From playground APIs - Royal Borough of Camden - categories = catering.bar

url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:51af9c5f68f826c4bf59b603a4f4efc54940f00101f90173ca000000000000c002069203184c6f6e646f6e20426f726f756768206f662043616d64656e&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'The Camden Assembly', 'old_name': 'Barfly', 'country': 'United Kingdom', 'country_code': 'gb', 'state': 'England', 'county': 'Greater London', 'city': 'London', 'postcode': 'NW1 8AN', 'district': 'London Borough of Camden', 'suburb': 'Chalk Farm', 'quarter': 'Primrose Hill', 'street': 'Chalk Farm Road', 'housenumber': '49', 'lon': -0.14923547464540332, 'lat': 51.5431079, 'state_code': 'ENG', 'formatted': 'The Camden Assembly, 49 Chalk Farm Road, London NW1 8AN, United Kingdom', 'address_line1': 'The Camden Assembly', 'address_line2': '49 Chalk Farm Road, London NW1 8AN, United Kingdom', 'categories': ['building', 'building.catering', 'catering', 'catering.bar', 'wheelchair', 'wheelchair.limited'], 'details': ['details', 'details.building', 'details.contact', 'details.facilities', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 
# ...

# %%
# To make data subscriptable
borough_data_3 = requests.get(url).json()

# %%
# Print the json (pretty printed)
print(json.dumps(borough_data_3, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -0.1492191052233455,
#                     51.543112823523465
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "The Camden Assembly",
#                 "address_line2": "49 Chalk Farm Road, London NW1 8AN, United Kingdom",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.bar",
#                     "wheelchair",
#                     "wheelchair.limited"
#                 ],
#                 "city": "London",
#                 "country": "United Kingdom",
#                 "country_code": "gb",
#                 "county": "Greater London",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
# ...

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Camd = len(borough_data_3["features"])
print(f"There are {number_of_bars_Camd} bars in Camden")
# Out:
# There are 78 bars in Camden

# %%
import requests

# From playground APIs - Royal Borough of Hammersmith & Fulham - categories = catering.bar

url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:511323c2898043ccbf59aab99d2d5dbf4940f00101f901a4d0020000000000c002069203284c6f6e646f6e20426f726f756768206f662048616d6d6572736d69746820616e642046756c68616d&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Elk Bar', 'country': 'United Kingdom', 'country_code': 'gb', 'state': 'England', 'county': 'Greater London', 'city': 'London', 'postcode': 'SW6 5UA', 'district': 'London Borough of Hammersmith and Fulham', 'neighbourhood': 'Wandon Estate', 'suburb': 'Walham Green', 'street': 'Fulham Road', 'housenumber': '587', 'lon': -0.19745471901161987, 'lat': 51.48031265, 'state_code': 'ENG', 'formatted': 'Elk Bar, 587 Fulham Road, London SW6 5UA, United Kingdom', 'address_line1': 'Elk Bar', 'address_line2': '587 Fulham Road, London SW6 5UA, United Kingdom', 'categories': ['catering', 'catering.bar'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Elk Bar', 'level': 0, 'osm_id': 151170957, 'amenity': 'bar', 'fhrs:id': 3450
# ...

# %%
# To make data subscriptable
borough_data_4 = requests.get(url).json()

# %%
# Print the json (pretty printed)
print(json.dumps(borough_data_4, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -0.19747266042353648,
#                     51.480282678596296
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Elk Bar",
#                 "address_line2": "587 Fulham Road, London SW6 5UA, United Kingdom",
#                 "categories": [
#                     "catering",
#                     "catering.bar"
#                 ],
#                 "city": "London",
#                 "country": "United Kingdom",
#                 "country_code": "gb",
#                 "county": "Greater London",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 587,
# ...

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Ham = len(borough_data_4["features"])
print(f"There are {number_of_bars_Ham} bars in Hammersmith & Fulham")
# Out:
# There are 18 bars in Hammersmith & Fulham

# %%
import requests

# From playground APIs - Royal Borough of Richmond-upon-Thames - categories = catering.bar

url = "https://api.geoapify.com/v2/places?categories=catering.bar&filter=place:51d6efe4217dfdd3bf59f373a8f2abb84940f00101f901f350020000000000c002069203264c6f6e646f6e20426f726f756768206f6620526963686d6f6e642075706f6e205468616d6573&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Sips & Bites', 'country': 'United Kingdom', 'country_code': 'gb', 'state': 'England', 'county': 'Greater London', 'city': 'London', 'postcode': 'SW13 9ER', 'district': 'London Borough of Richmond upon Thames', 'street': 'Castelnau', 'housenumber': '185', 'lon': -0.23370724999999087, 'lat': 51.48524755, 'state_code': 'ENG', 'formatted': 'Sips & Bites, 185 Castelnau, London SW13 9ER, United Kingdom', 'address_line1': 'Sips & Bites', 'address_line2': '185 Castelnau, London SW13 9ER, United Kingdom', 'categories': ['building', 'building.catering', 'building.commercial', 'catering', 'catering.bar', 'internet_access'], 'details': ['details.building', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Sips & Bites', 'leve
# ...

# %%
# To make data subscriptable
borough_data_5 = requests.get(url).json()

# %%
# Print the json (pretty printed)
print(json.dumps(borough_data_5, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -0.2337072499999953,
#                     51.485247549174495
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sips & Bites",
#                 "address_line2": "185 Castelnau, London SW13 9ER, United Kingdom",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.commercial",
#                     "catering",
#                     "catering.bar",
#                     "internet_access"
#                 ],
#                 "city": "London",
#                 "country": "United Kingdom",
#                 "country_code": "gb",
#                 "county": "Greater London",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
# ...

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_of_bars_Richm = len(borough_data_5["features"])
print(f"There are {number_of_bars_Richm} bars in Richmond upon Thames")
# Out:
# There are 11 bars in Richmond upon Thames

# %%
import pandas as pd
Boroughs_df = pd.DataFrame({"Borough":["Kensington and London", "Westminster", "Camden", "Hammersmith & Fulham", "Richmond upon Thames"],
                              "Number of Bars": [number_of_bars_Ken,number_of_bars_West,number_of_bars_Camd,number_of_bars_Ham,number_of_bars_Richm]
                                        
    
    
})
Boroughs_df.head()
# Out:
#                  Borough  Number of Bars
# 0  Kensington and London              34
# 1            Westminster             181
# 2                 Camden              78
# 3   Hammersmith & Fulham              18
# 4   Richmond upon Thames              11

# %%
import requests

# From playground APIs - Royal Borough of Kensington and London - categories = fast food

url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:51d6acea30389ac8bf59b8d8034327c04940f00101f90151ca000000000000c00206920327526f79616c20426f726f756768206f66204b656e73696e67746f6e20616e64204368656c736561&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
# print(response.json())

# %%
# To make data subscriptable
borough_data = requests.get(url).json()

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_Ken = len(borough_data["features"])
print(f"There are {number_fast_food_Ken} fast food places in Kensington and London")
# Out:
# There are 85 fast food places in Kensington and London

# %%
# From playground APIs - Royal Borough of Westminster - categories = fast food

url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:511fe19e1ebb89c4bf595caef541b8c14940f00101f90145ca000000000000c0020692031343697479206f6620576573746d696e73746572&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
#print(response.json())

# %%
# To make data subscriptable
borough_data_2 = requests.get(url).json()

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_West = len(borough_data_2["features"])
print(f"There are {number_fast_food_West} fast food places in Westminster")
# Out:
# There are 250 fast food places in Westminster

# %%
import requests

# From playground APIs - London borough of Camden - categories = fast food

url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:517efa79716926c4bf593e536c22f0c54940f00101f90173ca000000000000c002069203184c6f6e646f6e20426f726f756768206f662043616d64656e&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
# print(response.json())

# %%
# To make data subscriptable
borough_data_3 = requests.get(url).json()

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_Camd = len(borough_data_3["features"])
print(f"There are {number_fast_food_Camd} fast food places in Camden")
# Out:
# There are 250 fast food places in Camden

# %%
import requests

# From playground APIs - London borough of Hammersmith & Fulham - categories = fast food

url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:511323c2898043ccbf59aab99d2d5dbf4940f00101f901a4d0020000000000c002069203284c6f6e646f6e20426f726f756768206f662048616d6d6572736d69746820616e642046756c68616d&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
# print(response.json())

# %%
# To make data subscriptable
borough_data_4 = requests.get(url).json()

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_Ham = len(borough_data_4["features"])
print(f"There are {number_fast_food_Ham} fast food places in Hammersmith & Fulham")
# Out:
# There are 131 fast food places in Hammersmith & Fulham

# %%
import requests

# From playground APIs - London borough of Richmond-Upon-Thames - categories = fast food

url = "https://api.geoapify.com/v2/places?categories=catering.fast_food&filter=place:51bea4315a4755d5bf59b79c4b7155b54940c00208e2031967656f6e616d65733a6c6f63616c6974793a33333333313837&limit=250&apiKey=geoapify_key"
          
response = requests.get(url)
# print(response.json())

# %%
# To make data subscriptable
borough_data_5 = requests.get(url).json()

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_fast_food_Richm = len(borough_data_5["features"])
print(f"There are {number_fast_food_Richm} fast food places in Richmond upon Thames")
# Out:
# There are 108 fast food places in Richmond upon Thames

# %%
Boroughs_df["Number of Fast Food Places"]= [number_fast_food_Ken,number_fast_food_West,number_fast_food_Camd, number_fast_food_Ham,number_fast_food_Richm]
Boroughs_df
# Out:
#                  Borough  Number of Bars  Number of Fast Food Places
# 0  Kensington and London              34                          85
# 1            Westminster             181                         250
# 2                 Camden              78                         250
# 3   Hammersmith & Fulham              18                         131
# 4   Richmond upon Thames              11                         108

# %%
plt.bar(x= Boroughs_df['Borough'], height =Boroughs_df['Number of Fast Food Places'])
plt.xticks(rotation=45)
plt.xlabel("Boroughs")
plt.ylabel("Number of Fast Food Places")
plt.show()

# %%
plt.bar(x= Boroughs_df['Borough'], height =Boroughs_df['Number of Bars'])
plt.xticks(rotation=45)
plt.xlabel("Boroughs")
plt.ylabel("Number of Bars")
plt.show()
